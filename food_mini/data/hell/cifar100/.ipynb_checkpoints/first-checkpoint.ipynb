# %% [markdown]
# mean = {
# 'cifar10': (0.4914, 0.4822, 0.4465),
# 'cifar100': (0.5071, 0.4867, 0.4408),
# }
#
# std = {
# 'cifar10': (0.2023, 0.1994, 0.2010),
# 'cifar100': (0.2675, 0.2565, 0.2761),
# }

# %%
import torch
from torch import nn
import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms import ToTensor
from torchvision import datasets
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchinfo import summary
import torch.optim.lr_scheduler as lr_scheduler
from tqdm.auto import tqdm
from pathlib import Path
import random
from timeit import default_timer as timer

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from helper_functions import plot_loss_curves
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.2.0
# 0.17.0

# %%
torch.cuda.is_available()
device = "cuda"

# %%
# set up training data
# stats = ((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
data_transform_train = transforms.Compose([
    # transforms.TrivialAugmentWide(num_magnitude_bins=31),
    # transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
    # transforms.Normalize(*stats,inplace=True)
])

data_transform_test = transforms.Compose([
    transforms.ToTensor()
    # transforms.Normalize(*stats)
])

train_data = datasets.CIFAR100(root="Tdata",train=True,download=True,
                                  transform = data_transform_train,
                                  target_transform = None)

test_data = datasets.CIFAR100(root="Tdata",train=False,download=True,
                                  transform =data_transform_test,
                                  target_transform = None)

test_data_normal = datasets.CIFAR100(root="Tdata",train=False,download=True,
                                  target_transform = None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len(test_data),len(train_data)
# Out:
# (10000, 50000)

# %%
image , label = train_data[0]
class_names = train_data.classes
class_to_idx = train_data.class_to_idx

# %%
image , label = train_data[0]
print(f"image shape: {image.shape}")

fig = plt.figure(figsize=(9,9))
rows, cols = 4, 4
for i in range(1, rows*cols+1):
    random_idx = torch.randint(0,len(train_data),size=[1]).item()
    img, label = train_data[random_idx]
    fig.add_subplot(rows ,cols ,i)
    plt.imshow(img.permute(1,2,0).squeeze())
    plt.title(class_names[label])
    plt.axis(False);
# Out:
# image shape: torch.Size([3, 32, 32])

# %%
#set up the bach size hyper parameter
BATCH_SIZE = 100

# TURN DATA SETS INTO ITERABLES (BATCHES)

train_dataloader = DataLoader(dataset  = train_data,
                             batch_size=BATCH_SIZE,
                             shuffle=True)

test_dataloader = DataLoader(dataset  = test_data,
                             batch_size=BATCH_SIZE,
                             shuffle=False)

len(train_dataloader) , len(test_dataloader)
# Out:
# (500, 100)

# %%
class TinyVGG(nn.Module):
    """
    Model architecture that replicate the tinyvgg
    model from cnn explaner website.
    """
    def __init__(self, input_shape:int, hidden_units: int , output_shape : int):
        super().__init__()
        self.conv_block_1 = nn.Sequential(
        # creat a conv layer
        nn.Conv2d(in_channels= input_shape,
                 out_channels= hidden_units,
                 kernel_size=3,
                 stride = 1,
                 padding=1),
            nn.ReLU(),
            
            nn.Conv2d(in_channels= hidden_units,
                 out_channels= hidden_units,
                 kernel_size=3,
                 stride = 1,
                 padding=1),
            nn.ReLU(),
            
            nn.MaxPool2d(kernel_size=2)
        )
        
        self.conv_block_2= nn.Sequential(
            nn.Conv2d(in_channels= hidden_units,
                     out_channels= hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            
            nn.Conv2d(in_channels= hidden_units,
                     out_channels= hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            
            nn.MaxPool2d(kernel_size=2)        
        )
        
        
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=hidden_units*64,
                     out_features=  output_shape)
        )
        
    def forward(self,x):
        
        return self.classifier(self.conv_block_2(self.conv_block_1(x)))

# %%
model_0 = TinyVGG(input_shape=3 , hidden_units=10,output_shape=len(class_names))
# model_2 = TinyVGGV2(input_shape=3 , hidden_units=10,output_shape=len(class_names))
image_batch , label_batch = next(iter(train_dataloader))
image_batch.shape , label_batch.shape
# model_2(image_batch)
# Out:
# (torch.Size([100, 3, 32, 32]), torch.Size([100]))

# %%
summary(model_0 , input_size=[1,3,32,32])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGG                                  [1, 100]                  --
# ├─Sequential: 1-1                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-1                       [1, 10, 32, 32]           280
# │    └─ReLU: 2-2                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-3                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-4                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 16, 16]           --
# ├─Sequential: 1-2                        [1, 10, 8, 8]             --
# │    └─Conv2d: 2-6                       [1, 10, 16, 16]           910
# │    └─ReLU: 2-7                         [1, 10, 16, 16]           --
# │    └─Conv2d: 2-8                       [1, 10, 16, 16]           910
# │    └─ReLU: 2-9                         [1, 10, 16, 16]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 8, 8]             --
# ├─Sequential: 1-3                        [1, 100]                  --
# │    └─Flatten: 2-11                     [1, 640]                  --
# │    └─Linear: 2-12                      [1, 100]                  64,100
# ==========================================================================================
# Total params: 67,110
# Trainable params: 67,110
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.75
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.21
# Params size (MB): 0.27
# Estimated Total Size (MB): 0.49
# ==========================================================================================

# %%
def train_step(model : torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              optimizer: torch.optim.Optimizer , ):
    model.train()
    
    train_loss ,train_acc = 0,0
    
    for batch, (x,y) in enumerate(dataloader):
        x,y = x.to(device),y.to(device)
        y_pred = model(x)
        
        loss = loss_fn(y_pred,y)
        train_loss += loss.item()
        
        optimizer.zero_grad()
        
        
        loss.backward()
        
        optimizer.step()
        
        
        
        y_pred_class = torch.argmax(torch.softmax(y_pred ,dim=1),dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)
        
        

    train_loss = train_loss/ len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss ,train_acc



def test_step(model : torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    
    model.eval()
    
    test_loss , test_acc = 0,0
    
    with torch.inference_mode():
        
        for batch,(x,y) in enumerate(dataloader):
            x,y = x.to(device),y.to(device)
            
            test_pred_logits = model(x)
            
            loss = loss_fn(test_pred_logits , y)
            test_loss += loss.item()
            
            test_pred_labels  =  test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
            
        test_loss = test_loss / len(dataloader)
        test_acc = test_acc /len(dataloader)
        return test_loss , test_acc

    
    

def train(model_name: str ,
    model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
         
          loss_fn:torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):
    
    # create an empty result dictionary
    results = {"train_loss" : [],
              "train_acc": [],
              "test_loss": [],
              "test_acc": []}
    max_acc = 0
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model = model,
                                           dataloader=train_dataloader,
                                           loss_fn = loss_fn,
                                           optimizer=optimizer )
        
        test_loss, test_acc = test_step(model = model,
                                           dataloader=test_dataloader,
                                           loss_fn = loss_fn)
        
        
         # print whats happening
        print(f"Epoch: {epoch} | Train loss: {train_loss: .4f} | Train acc: {train_acc: .4f} | Test loss: {test_loss: .4f} | Test acc: {test_acc: .4f} ")
        
        
        
        if test_acc > max_acc:
            #1.create models directory
            MODEL_PATH =  Path("models")
            MODEL_PATH.mkdir(parents=True, exist_ok=True)

            # 2. creat model save path
            MODEL_NAME = f"{model_name}.pth"
            MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

            #save the model stat dict
            print(f"saving model to: {MODEL_SAVE_PATH}")
            torch.save(obj=model.state_dict(), f=MODEL_SAVE_PATH)
            max_acc = test_acc
            
        
       
        # update result dic
        
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)
        
    return results

# %%
NUM_EPOCHS = 200

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_0.parameters(),
                            lr = 0.001)

from timeit import default_timer as timer
start_time = timer()
model_0_results = train(model_name="tiny_vgg_w_s",model= model_0,
                       train_dataloader=  train_dataloader,
                       test_dataloader= test_dataloader,
                       optimizer = optimizer,
                       loss_fn=loss_fn,
                       epochs=NUM_EPOCHS)
end_time = timer()
print(f"total training time for model_0: {end_time - start_time:.3f} seconds")
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch: 0 | Train loss:  2.1966 | Train acc:  0.4410 | Test loss:  2.6185 | Test acc:  0.3599
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 1 | Train loss:  2.1790 | Train acc:  0.4434 | Test loss:  2.6139 | Test acc:  0.3603
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 2 | Train loss:  2.1820 | Train acc:  0.4435 | Test loss:  2.5983 | Test acc:  0.3636
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 3 | Train loss:  2.1636 | Train acc:  0.4464 | Test loss:  2.6582 | Test acc:  0.3472
# Epoch: 4 | Train loss:  2.1610 | Train acc:  0.4479 | Test loss:  2.5913 | Test acc:  0.3626
# Epoch: 5 | Train loss:  2.1569 | Train acc:  0.4491 | Test loss:  2.6078 | Test acc:  0.3609
# Epoch: 6 | Train loss:  2.1541 | Train acc:  0.4519 | Test loss:  2.5870 | Test acc:  0.3672
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 7 | Train loss:  2.1399 | Train acc:  0.4529 | Test loss:  2.6148 | Test acc:  0.3611
# Epoch: 8 | Train loss:  2.1366 | Train acc:  0.4528 | Test loss:  2.6367 | Test acc:  0.3568
# Epoch: 9 | Train loss:  2.1278 | Train acc:  0.4544 | Test loss:  2.5972 | Test acc:  0.3692
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 10 | Train loss:  2.1166 | Train acc:  0.4580 | Test loss:  2.5928 | Test acc:  0.3657
# Epoch: 11 | Train loss:  2.1108 | Train acc:  0.4584 | Test loss:  2.6351 | Test acc:  0.3563
# Epoch: 12 | Train loss:  2.1119 | Train acc:  0.4568 | Test loss:  2.6077 | Test acc:  0.3613
# Epoch: 13 | Train loss:  2.1077 | Train acc:  0.4607 | Test loss:  2.5865 | Test acc:  0.3684
# Epoch: 14 | Train loss:  2.0865 | Train acc:  0.4630 | Test loss:  2.6170 | Test acc:  0.3666
# Epoch: 15 | Train loss:  2.0919 | Train acc:  0.4620 | Test loss:  2.5904 | Test acc:  0.3676
# Epoch: 16 | Train loss:  2.0897 | Train acc:  0.4645 | Test loss:  2.5848 | Test acc:  0.3673
# Epoch: 17 | Train loss:  2.0839 | Train acc:  0.4622 | Test loss:  2.6059 | Test acc:  0.3631
# Epoch: 18 | Train loss:  2.0776 | Train acc:  0.4662 | Test loss:  2.5770 | Test acc:  0.3682
# Epoch: 19 | Train loss:  2.0736 | Train acc:  0.4674 | Test loss:  2.5823 | Test acc:  0.3672
# Epoch: 20 | Train loss:  2.0671 | Train acc:  0.4667 | Test loss:  2.5592 | Test acc:  0.3733
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 21 | Train loss:  2.0654 | Train acc:  0.4705 | Test loss:  2.5937 | Test acc:  0.3714
# Epoch: 22 | Train loss:  2.0627 | Train acc:  0.4678 | Test loss:  2.5648 | Test acc:  0.3726
# Epoch: 23 | Train loss:  2.0539 | Train acc:  0.4691 | Test loss:  2.5684 | Test acc:  0.3744
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 24 | Train loss:  2.0564 | Train acc:  0.4689 | Test loss:  2.6070 | Test acc:  0.3684
# Epoch: 25 | Train loss:  2.0462 | Train acc:  0.4734 | Test loss:  2.5606 | Test acc:  0.3724
# Epoch: 26 | Train loss:  2.0388 | Train acc:  0.4740 | Test loss:  2.5841 | Test acc:  0.3691
# Epoch: 27 | Train loss:  2.0418 | Train acc:  0.4727 | Test loss:  2.5642 | Test acc:  0.3716
# Epoch: 28 | Train loss:  2.0340 | Train acc:  0.4746 | Test loss:  2.6109 | Test acc:  0.3668
# Epoch: 29 | Train loss:  2.0323 | Train acc:  0.4761 | Test loss:  2.5864 | Test acc:  0.3676
# Epoch: 30 | Train loss:  2.0274 | Train acc:  0.4769 | Test loss:  2.5765 | Test acc:  0.3706
# Epoch: 31 | Train loss:  2.0201 | Train acc:  0.4771 | Test loss:  2.5785 | Test acc:  0.3678
# Epoch: 32 | Train loss:  2.0251 | Train acc:  0.4769 | Test loss:  2.6017 | Test acc:  0.3647
# Epoch: 33 | Train loss:  2.0173 | Train acc:  0.4804 | Test loss:  2.5641 | Test acc:  0.3714
# Epoch: 34 | Train loss:  2.0182 | Train acc:  0.4769 | Test loss:  2.5705 | Test acc:  0.3718
# Epoch: 35 | Train loss:  2.0149 | Train acc:  0.4779 | Test loss:  2.5948 | Test acc:  0.3694
# Epoch: 36 | Train loss:  2.0081 | Train acc:  0.4795 | Test loss:  2.5592 | Test acc:  0.3715
# Epoch: 37 | Train loss:  2.0100 | Train acc:  0.4785 | Test loss:  2.5784 | Test acc:  0.3673
# Epoch: 38 | Train loss:  1.9995 | Train acc:  0.4832 | Test loss:  2.5761 | Test acc:  0.3730
# Epoch: 39 | Train loss:  2.0038 | Train acc:  0.4802 | Test loss:  2.5623 | Test acc:  0.3750
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 40 | Train loss:  1.9987 | Train acc:  0.4830 | Test loss:  2.5810 | Test acc:  0.3682
# Epoch: 41 | Train loss:  1.9957 | Train acc:  0.4811 | Test loss:  2.5968 | Test acc:  0.3636
# Epoch: 42 | Train loss:  1.9947 | Train acc:  0.4820 | Test loss:  2.5647 | Test acc:  0.3729
# Epoch: 43 | Train loss:  1.9832 | Train acc:  0.4861 | Test loss:  2.5581 | Test acc:  0.3789
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 44 | Train loss:  1.9811 | Train acc:  0.4868 | Test loss:  2.5708 | Test acc:  0.3760
# Epoch: 45 | Train loss:  1.9807 | Train acc:  0.4860 | Test loss:  2.5645 | Test acc:  0.3756
# Epoch: 46 | Train loss:  1.9769 | Train acc:  0.4860 | Test loss:  2.5741 | Test acc:  0.3751
# Epoch: 47 | Train loss:  1.9763 | Train acc:  0.4854 | Test loss:  2.5679 | Test acc:  0.3755
# Epoch: 48 | Train loss:  1.9766 | Train acc:  0.4876 | Test loss:  2.5625 | Test acc:  0.3788
# Epoch: 49 | Train loss:  1.9714 | Train acc:  0.4870 | Test loss:  2.5489 | Test acc:  0.3779
# Epoch: 50 | Train loss:  1.9700 | Train acc:  0.4887 | Test loss:  2.5468 | Test acc:  0.3789
# Epoch: 51 | Train loss:  1.9645 | Train acc:  0.4888 | Test loss:  2.5541 | Test acc:  0.3789
# Epoch: 52 | Train loss:  1.9637 | Train acc:  0.4906 | Test loss:  2.5711 | Test acc:  0.3711
# Epoch: 53 | Train loss:  1.9611 | Train acc:  0.4920 | Test loss:  2.5725 | Test acc:  0.3779
# Epoch: 54 | Train loss:  1.9607 | Train acc:  0.4902 | Test loss:  2.5465 | Test acc:  0.3740
# Epoch: 55 | Train loss:  1.9547 | Train acc:  0.4933 | Test loss:  2.5602 | Test acc:  0.3741
# Epoch: 56 | Train loss:  1.9511 | Train acc:  0.4920 | Test loss:  2.5689 | Test acc:  0.3768
# Epoch: 57 | Train loss:  1.9523 | Train acc:  0.4914 | Test loss:  2.6094 | Test acc:  0.3665
# Epoch: 58 | Train loss:  1.9556 | Train acc:  0.4902 | Test loss:  2.5422 | Test acc:  0.3766
# Epoch: 59 | Train loss:  1.9491 | Train acc:  0.4926 | Test loss:  2.5961 | Test acc:  0.3690
# Epoch: 60 | Train loss:  1.9460 | Train acc:  0.4936 | Test loss:  2.5680 | Test acc:  0.3747
# Epoch: 61 | Train loss:  1.9393 | Train acc:  0.4961 | Test loss:  2.5504 | Test acc:  0.3759
# Epoch: 62 | Train loss:  1.9389 | Train acc:  0.4967 | Test loss:  2.5704 | Test acc:  0.3757
# Epoch: 63 | Train loss:  1.9454 | Train acc:  0.4934 | Test loss:  2.5559 | Test acc:  0.3788
# Epoch: 64 | Train loss:  1.9398 | Train acc:  0.4956 | Test loss:  2.5655 | Test acc:  0.3759
# Epoch: 65 | Train loss:  1.9331 | Train acc:  0.4956 | Test loss:  2.5473 | Test acc:  0.3805
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 66 | Train loss:  1.9280 | Train acc:  0.4983 | Test loss:  2.5700 | Test acc:  0.3784
# Epoch: 67 | Train loss:  1.9348 | Train acc:  0.4942 | Test loss:  2.5541 | Test acc:  0.3762
# Epoch: 68 | Train loss:  1.9325 | Train acc:  0.4952 | Test loss:  2.5675 | Test acc:  0.3776
# Epoch: 69 | Train loss:  1.9303 | Train acc:  0.4962 | Test loss:  2.5435 | Test acc:  0.3810
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 70 | Train loss:  1.9304 | Train acc:  0.4981 | Test loss:  2.5362 | Test acc:  0.3808
# Epoch: 71 | Train loss:  1.9218 | Train acc:  0.4993 | Test loss:  2.6134 | Test acc:  0.3705
# Epoch: 72 | Train loss:  1.9177 | Train acc:  0.5020 | Test loss:  2.5638 | Test acc:  0.3811
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 73 | Train loss:  1.9175 | Train acc:  0.4968 | Test loss:  2.5509 | Test acc:  0.3819
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 74 | Train loss:  1.9216 | Train acc:  0.4981 | Test loss:  2.5618 | Test acc:  0.3830
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 75 | Train loss:  1.9236 | Train acc:  0.4994 | Test loss:  2.5446 | Test acc:  0.3792
# Epoch: 76 | Train loss:  1.9186 | Train acc:  0.4994 | Test loss:  2.5496 | Test acc:  0.3783
# Epoch: 77 | Train loss:  1.9084 | Train acc:  0.5019 | Test loss:  2.5542 | Test acc:  0.3802
# Epoch: 78 | Train loss:  1.9114 | Train acc:  0.5004 | Test loss:  2.5717 | Test acc:  0.3809
# Epoch: 79 | Train loss:  1.9116 | Train acc:  0.5023 | Test loss:  2.5677 | Test acc:  0.3792
# Epoch: 80 | Train loss:  1.9072 | Train acc:  0.5005 | Test loss:  2.5522 | Test acc:  0.3793
# Epoch: 81 | Train loss:  1.9013 | Train acc:  0.5016 | Test loss:  2.5638 | Test acc:  0.3802
# Epoch: 82 | Train loss:  1.9038 | Train acc:  0.5006 | Test loss:  2.5719 | Test acc:  0.3761
# Epoch: 83 | Train loss:  1.9041 | Train acc:  0.5016 | Test loss:  2.5797 | Test acc:  0.3784
# Epoch: 84 | Train loss:  1.9075 | Train acc:  0.5014 | Test loss:  2.5618 | Test acc:  0.3784
# Epoch: 85 | Train loss:  1.8988 | Train acc:  0.5040 | Test loss:  2.5651 | Test acc:  0.3821
# Epoch: 86 | Train loss:  1.8997 | Train acc:  0.5016 | Test loss:  2.5865 | Test acc:  0.3771
# Epoch: 87 | Train loss:  1.9046 | Train acc:  0.5038 | Test loss:  2.5485 | Test acc:  0.3841
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 88 | Train loss:  1.8962 | Train acc:  0.5028 | Test loss:  2.5444 | Test acc:  0.3797
# Epoch: 89 | Train loss:  1.8976 | Train acc:  0.5035 | Test loss:  2.5347 | Test acc:  0.3841
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 90 | Train loss:  1.8970 | Train acc:  0.5058 | Test loss:  2.5722 | Test acc:  0.3745
# Epoch: 91 | Train loss:  1.8890 | Train acc:  0.5048 | Test loss:  2.5515 | Test acc:  0.3774
# Epoch: 92 | Train loss:  1.8923 | Train acc:  0.5042 | Test loss:  2.5541 | Test acc:  0.3829
# Epoch: 93 | Train loss:  1.8845 | Train acc:  0.5066 | Test loss:  2.5712 | Test acc:  0.3719
# Epoch: 94 | Train loss:  1.8876 | Train acc:  0.5079 | Test loss:  2.5453 | Test acc:  0.3798
# Epoch: 95 | Train loss:  1.8866 | Train acc:  0.5043 | Test loss:  2.5792 | Test acc:  0.3741
# Epoch: 96 | Train loss:  1.8884 | Train acc:  0.5067 | Test loss:  2.5451 | Test acc:  0.3825
# Epoch: 97 | Train loss:  1.8875 | Train acc:  0.5045 | Test loss:  2.5502 | Test acc:  0.3803
# Epoch: 98 | Train loss:  1.8868 | Train acc:  0.5046 | Test loss:  2.6076 | Test acc:  0.3771
# Epoch: 99 | Train loss:  1.8808 | Train acc:  0.5070 | Test loss:  2.5507 | Test acc:  0.3812
# Epoch: 100 | Train loss:  1.8791 | Train acc:  0.5062 | Test loss:  2.5598 | Test acc:  0.3851
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 101 | Train loss:  1.8756 | Train acc:  0.5070 | Test loss:  2.5884 | Test acc:  0.3806
# Epoch: 102 | Train loss:  1.8808 | Train acc:  0.5059 | Test loss:  2.5525 | Test acc:  0.3798
# Epoch: 103 | Train loss:  1.8810 | Train acc:  0.5060 | Test loss:  2.5416 | Test acc:  0.3821
# Epoch: 104 | Train loss:  1.8778 | Train acc:  0.5056 | Test loss:  2.5523 | Test acc:  0.3848
# Epoch: 105 | Train loss:  1.8735 | Train acc:  0.5091 | Test loss:  2.5725 | Test acc:  0.3793
# Epoch: 106 | Train loss:  1.8798 | Train acc:  0.5086 | Test loss:  2.5636 | Test acc:  0.3796
# Epoch: 107 | Train loss:  1.8733 | Train acc:  0.5098 | Test loss:  2.5508 | Test acc:  0.3768
# Epoch: 108 | Train loss:  1.8731 | Train acc:  0.5094 | Test loss:  2.5464 | Test acc:  0.3823
# Epoch: 109 | Train loss:  1.8691 | Train acc:  0.5110 | Test loss:  2.5458 | Test acc:  0.3830
# Epoch: 110 | Train loss:  1.8689 | Train acc:  0.5086 | Test loss:  2.5274 | Test acc:  0.3863
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 111 | Train loss:  1.8637 | Train acc:  0.5096 | Test loss:  2.5470 | Test acc:  0.3861
# Epoch: 112 | Train loss:  1.8614 | Train acc:  0.5114 | Test loss:  2.5555 | Test acc:  0.3854
# Epoch: 113 | Train loss:  1.8632 | Train acc:  0.5100 | Test loss:  2.5560 | Test acc:  0.3814
# Epoch: 114 | Train loss:  1.8665 | Train acc:  0.5095 | Test loss:  2.5782 | Test acc:  0.3799
# Epoch: 115 | Train loss:  1.8661 | Train acc:  0.5100 | Test loss:  2.5515 | Test acc:  0.3865
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 116 | Train loss:  1.8636 | Train acc:  0.5106 | Test loss:  2.5650 | Test acc:  0.3857
# Epoch: 117 | Train loss:  1.8677 | Train acc:  0.5100 | Test loss:  2.5524 | Test acc:  0.3848
# Epoch: 118 | Train loss:  1.8608 | Train acc:  0.5124 | Test loss:  2.5604 | Test acc:  0.3841
# Epoch: 119 | Train loss:  1.8586 | Train acc:  0.5118 | Test loss:  2.5658 | Test acc:  0.3821
# Epoch: 120 | Train loss:  1.8644 | Train acc:  0.5113 | Test loss:  2.5462 | Test acc:  0.3858
# Epoch: 121 | Train loss:  1.8588 | Train acc:  0.5120 | Test loss:  2.5784 | Test acc:  0.3817
# Epoch: 122 | Train loss:  1.8560 | Train acc:  0.5130 | Test loss:  2.5610 | Test acc:  0.3825
# Epoch: 123 | Train loss:  1.8536 | Train acc:  0.5127 | Test loss:  2.5981 | Test acc:  0.3786
# Epoch: 124 | Train loss:  1.8527 | Train acc:  0.5123 | Test loss:  2.5475 | Test acc:  0.3821
# Epoch: 125 | Train loss:  1.8506 | Train acc:  0.5154 | Test loss:  2.5954 | Test acc:  0.3785
# Epoch: 126 | Train loss:  1.8575 | Train acc:  0.5120 | Test loss:  2.5440 | Test acc:  0.3865
# Epoch: 127 | Train loss:  1.8525 | Train acc:  0.5134 | Test loss:  2.5457 | Test acc:  0.3804
# Epoch: 128 | Train loss:  1.8517 | Train acc:  0.5130 | Test loss:  2.5699 | Test acc:  0.3791
# Epoch: 129 | Train loss:  1.8464 | Train acc:  0.5170 | Test loss:  2.5842 | Test acc:  0.3776
# Epoch: 130 | Train loss:  1.8521 | Train acc:  0.5128 | Test loss:  2.5874 | Test acc:  0.3730
# Epoch: 131 | Train loss:  1.8450 | Train acc:  0.5160 | Test loss:  2.5510 | Test acc:  0.3831
# Epoch: 132 | Train loss:  1.8494 | Train acc:  0.5141 | Test loss:  2.5334 | Test acc:  0.3865
# Epoch: 133 | Train loss:  1.8527 | Train acc:  0.5121 | Test loss:  2.5431 | Test acc:  0.3828
# Epoch: 134 | Train loss:  1.8506 | Train acc:  0.5133 | Test loss:  2.6029 | Test acc:  0.3740
# Epoch: 135 | Train loss:  1.8406 | Train acc:  0.5132 | Test loss:  2.5775 | Test acc:  0.3800
# Epoch: 136 | Train loss:  1.8351 | Train acc:  0.5160 | Test loss:  2.5774 | Test acc:  0.3783
# Epoch: 137 | Train loss:  1.8414 | Train acc:  0.5149 | Test loss:  2.5533 | Test acc:  0.3804
# Epoch: 138 | Train loss:  1.8384 | Train acc:  0.5182 | Test loss:  2.5517 | Test acc:  0.3850
# Epoch: 139 | Train loss:  1.8404 | Train acc:  0.5132 | Test loss:  2.5545 | Test acc:  0.3820
# Epoch: 140 | Train loss:  1.8349 | Train acc:  0.5163 | Test loss:  2.5637 | Test acc:  0.3850
# Epoch: 141 | Train loss:  1.8441 | Train acc:  0.5158 | Test loss:  2.5661 | Test acc:  0.3822
# Epoch: 142 | Train loss:  1.8370 | Train acc:  0.5181 | Test loss:  2.5582 | Test acc:  0.3845
# Epoch: 143 | Train loss:  1.8406 | Train acc:  0.5169 | Test loss:  2.5573 | Test acc:  0.3833
# Epoch: 144 | Train loss:  1.8416 | Train acc:  0.5180 | Test loss:  2.5702 | Test acc:  0.3790
# Epoch: 145 | Train loss:  1.8378 | Train acc:  0.5181 | Test loss:  2.5718 | Test acc:  0.3817
# Epoch: 146 | Train loss:  1.8345 | Train acc:  0.5171 | Test loss:  2.5608 | Test acc:  0.3864
# Epoch: 147 | Train loss:  1.8285 | Train acc:  0.5203 | Test loss:  2.5516 | Test acc:  0.3827
# Epoch: 148 | Train loss:  1.8280 | Train acc:  0.5188 | Test loss:  2.5621 | Test acc:  0.3828
# Epoch: 149 | Train loss:  1.8346 | Train acc:  0.5188 | Test loss:  2.5671 | Test acc:  0.3772
# Epoch: 150 | Train loss:  1.8326 | Train acc:  0.5158 | Test loss:  2.5573 | Test acc:  0.3810
# Epoch: 151 | Train loss:  1.8285 | Train acc:  0.5163 | Test loss:  2.5982 | Test acc:  0.3806
# Epoch: 152 | Train loss:  1.8348 | Train acc:  0.5192 | Test loss:  2.5736 | Test acc:  0.3780
# Epoch: 153 | Train loss:  1.8298 | Train acc:  0.5179 | Test loss:  2.5781 | Test acc:  0.3814
# Epoch: 154 | Train loss:  1.8355 | Train acc:  0.5170 | Test loss:  2.5635 | Test acc:  0.3807
# Epoch: 155 | Train loss:  1.8290 | Train acc:  0.5182 | Test loss:  2.5427 | Test acc:  0.3801
# Epoch: 156 | Train loss:  1.8335 | Train acc:  0.5169 | Test loss:  2.5599 | Test acc:  0.3794
# Epoch: 157 | Train loss:  1.8316 | Train acc:  0.5186 | Test loss:  2.5566 | Test acc:  0.3799
# Epoch: 158 | Train loss:  1.8299 | Train acc:  0.5174 | Test loss:  2.5674 | Test acc:  0.3811
# Epoch: 159 | Train loss:  1.8272 | Train acc:  0.5182 | Test loss:  2.5746 | Test acc:  0.3822
# Epoch: 160 | Train loss:  1.8214 | Train acc:  0.5208 | Test loss:  2.5802 | Test acc:  0.3799
# Epoch: 161 | Train loss:  1.8277 | Train acc:  0.5191 | Test loss:  2.5541 | Test acc:  0.3830
# Epoch: 162 | Train loss:  1.8216 | Train acc:  0.5188 | Test loss:  2.5760 | Test acc:  0.3819
# Epoch: 163 | Train loss:  1.8210 | Train acc:  0.5217 | Test loss:  2.5680 | Test acc:  0.3855
# Epoch: 164 | Train loss:  1.8202 | Train acc:  0.5223 | Test loss:  2.5618 | Test acc:  0.3821
# Epoch: 165 | Train loss:  1.8229 | Train acc:  0.5218 | Test loss:  2.5775 | Test acc:  0.3839
# Epoch: 166 | Train loss:  1.8271 | Train acc:  0.5181 | Test loss:  2.5819 | Test acc:  0.3762
# Epoch: 167 | Train loss:  1.8214 | Train acc:  0.5215 | Test loss:  2.5625 | Test acc:  0.3846
# Epoch: 168 | Train loss:  1.8180 | Train acc:  0.5231 | Test loss:  2.5777 | Test acc:  0.3868
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 169 | Train loss:  1.8166 | Train acc:  0.5219 | Test loss:  2.5850 | Test acc:  0.3791
# Epoch: 170 | Train loss:  1.8193 | Train acc:  0.5205 | Test loss:  2.5931 | Test acc:  0.3764
# Epoch: 171 | Train loss:  1.8179 | Train acc:  0.5216 | Test loss:  2.5690 | Test acc:  0.3837
# Epoch: 172 | Train loss:  1.8196 | Train acc:  0.5206 | Test loss:  2.5793 | Test acc:  0.3835
# Epoch: 173 | Train loss:  1.8192 | Train acc:  0.5220 | Test loss:  2.5676 | Test acc:  0.3820
# Epoch: 174 | Train loss:  1.8148 | Train acc:  0.5243 | Test loss:  2.5497 | Test acc:  0.3822
# Epoch: 175 | Train loss:  1.8181 | Train acc:  0.5211 | Test loss:  2.5639 | Test acc:  0.3844
# Epoch: 176 | Train loss:  1.8158 | Train acc:  0.5203 | Test loss:  2.5682 | Test acc:  0.3858
# Epoch: 177 | Train loss:  1.8134 | Train acc:  0.5225 | Test loss:  2.5608 | Test acc:  0.3864
# Epoch: 178 | Train loss:  1.8212 | Train acc:  0.5183 | Test loss:  2.5665 | Test acc:  0.3773
# Epoch: 179 | Train loss:  1.8124 | Train acc:  0.5213 | Test loss:  2.5613 | Test acc:  0.3858
# Epoch: 180 | Train loss:  1.8117 | Train acc:  0.5227 | Test loss:  2.5763 | Test acc:  0.3844
# Epoch: 181 | Train loss:  1.8157 | Train acc:  0.5222 | Test loss:  2.5811 | Test acc:  0.3838
# Epoch: 182 | Train loss:  1.8054 | Train acc:  0.5236 | Test loss:  2.5780 | Test acc:  0.3821
# Epoch: 183 | Train loss:  1.8116 | Train acc:  0.5239 | Test loss:  2.5720 | Test acc:  0.3854
# Epoch: 184 | Train loss:  1.8141 | Train acc:  0.5209 | Test loss:  2.5724 | Test acc:  0.3852
# Epoch: 185 | Train loss:  1.8120 | Train acc:  0.5231 | Test loss:  2.5809 | Test acc:  0.3841
# Epoch: 186 | Train loss:  1.8089 | Train acc:  0.5234 | Test loss:  2.5389 | Test acc:  0.3895
# saving model to: models\tiny_vgg_w_s.pth
# Epoch: 187 | Train loss:  1.8150 | Train acc:  0.5225 | Test loss:  2.5654 | Test acc:  0.3810
# Epoch: 188 | Train loss:  1.8042 | Train acc:  0.5229 | Test loss:  2.5528 | Test acc:  0.3801
# Epoch: 189 | Train loss:  1.8116 | Train acc:  0.5233 | Test loss:  2.5907 | Test acc:  0.3771
# Epoch: 190 | Train loss:  1.8122 | Train acc:  0.5231 | Test loss:  2.5669 | Test acc:  0.3809
# Epoch: 191 | Train loss:  1.8077 | Train acc:  0.5242 | Test loss:  2.5433 | Test acc:  0.3824
# Epoch: 192 | Train loss:  1.8099 | Train acc:  0.5255 | Test loss:  2.5999 | Test acc:  0.3823
# Epoch: 193 | Train loss:  1.8142 | Train acc:  0.5217 | Test loss:  2.5818 | Test acc:  0.3800
# Epoch: 194 | Train loss:  1.8062 | Train acc:  0.5251 | Test loss:  2.5805 | Test acc:  0.3847
# Epoch: 195 | Train loss:  1.8055 | Train acc:  0.5248 | Test loss:  2.5653 | Test acc:  0.3871
# Epoch: 196 | Train loss:  1.8039 | Train acc:  0.5249 | Test loss:  2.5500 | Test acc:  0.3854
# Epoch: 197 | Train loss:  1.8046 | Train acc:  0.5247 | Test loss:  2.5528 | Test acc:  0.3846
# Epoch: 198 | Train loss:  1.7986 | Train acc:  0.5237 | Test loss:  2.5522 | Test acc:  0.3864
# Epoch: 199 | Train loss:  1.8008 | Train acc:  0.5253 | Test loss:  2.5677 | Test acc:  0.3833
# total training time for model_0: 5045.529 seconds

# %%
plot_loss_curves(model_0_results)

# %%
# random.seed(42)
test_samples = []
test_labels = []
for sample , label in random.sample(list(test_data), k = 9):
    test_samples.append(sample)
    test_labels.append(label)
    
def make_predictions(model: torch.nn.Module,
                    data: list):
    pred_probs = []
    model.eval()
    with torch.inference_mode():
        for sample in data:
            sample = sample.to(device)
            # prepare the sample
            sample = torch.unsqueeze(sample , dim=0 )
            
            #forward pass
            pred_logit = model(sample)
            
            #get prediction probability
            pred_prob = torch.softmax(pred_logit.squeeze(),dim=0)
            
            pred_probs.append(pred_prob)
            
            
    return torch.stack(pred_probs)

pred_probs = make_predictions(model=model_0,
                              data= test_samples)
pred_classes = pred_probs.argmax(dim=1)
# plot pred
plt.figure(figsize= (9,9))
nrows = 3
ncols = 3
for i , sample in enumerate(test_samples):
    
    plt.subplot(nrows , ncols , i+1)
    
    plt.imshow(sample.permute(1,2,0).squeeze())
    
    pred_label = class_names[pred_classes[i]]
    
    truth_label = class_names[test_labels[i]]
    
    title_text = f"Pred: {pred_label} | Truth: {truth_label}"
    
    if pred_label ==  truth_label:
        plt.title(title_text , fontsize = 10,c = "g")
    else:
        plt.title(title_text , fontsize = 10,c = "r")
    plt.axis(False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
y_preds = []
x_test = []
model_0.eval()
with torch.inference_mode():
    for x,y in tqdm(test_dataloader,desc = "making predictions..."):
        x,y = x.to(device),y.to(device)
        y_logit = model_0(x)
        
        y_pred = torch.softmax(y_logit.squeeze(),dim=0).argmax(dim=1)
        
        y_preds.append(y_pred.to('cpu'))
        x_test.append(y.to('cpu'))
        
# print(y_preds)
y_pred_tensor = torch.cat(y_preds)
x_test_cat = torch.cat(x_test)
cm = confusion_matrix(y_pred_tensor,x_test_cat)
disp = ConfusionMatrixDisplay(cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(25,25))
disp.plot(ax=ax ,cmap=plt.cm.Blues)
# Out:
# making predictions...:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
model_0 = TinyVGG(input_shape=3 , hidden_units=10,output_shape=len(class_names))

model_0.load_state_dict(torch.load(f=MODEL_SAVE_PATH))

# %% [markdown]
# # tinny with normalize and sch

# %%
# set up training data
stats = ((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
data_transform_train = transforms.Compose([
    # transforms.TrivialAugmentWide(num_magnitude_bins=31),
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(*stats,inplace=True)
])

data_transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*stats)
])

train_data = datasets.CIFAR100(root="Tdata",train=True,download=True,
                                  transform = data_transform_train,
                                  target_transform = None)

test_data = datasets.CIFAR100(root="Tdata",train=False,download=True,
                                  transform =data_transform_test,
                                  target_transform = None)

test_data_normal = datasets.CIFAR100(root="Tdata",train=False,download=True,
                                  target_transform = None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
image , label = train_data[0]
class_names = train_data.classes
class_to_idx = train_data.class_to_idx

# %%
image , label = train_data[0]
print(f"image shape: {image.shape}")

fig = plt.figure(figsize=(9,9))
rows, cols = 4, 4
for i in range(1, rows*cols+1):
    random_idx = torch.randint(0,len(train_data),size=[1]).item()
    img, label = train_data[random_idx]
    fig.add_subplot(rows ,cols ,i)
    plt.imshow(img.permute(1,2,0).squeeze())
    plt.title(class_names[label])
    plt.axis(False);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape: torch.Size([3, 32, 32])

# %%
def train_step(model : torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              optimizer: torch.optim.Optimizer , scheduler):
    model.train()
    
    train_loss ,train_acc = 0,0
    
    for batch, (x,y) in enumerate(dataloader):
        x,y = x.to(device),y.to(device)
        y_pred = model(x)
        
        loss = loss_fn(y_pred,y)
        train_loss += loss.item()
        
        optimizer.zero_grad()
        
        
        loss.backward()
        
        optimizer.step()
        
        
        
        y_pred_class = torch.argmax(torch.softmax(y_pred ,dim=1),dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)
        
        
    scheduler.step()   
    train_loss = train_loss/ len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss ,train_acc



def test_step(model : torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
    
    model.eval()
    
    test_loss , test_acc = 0,0
    
    with torch.inference_mode():
        
        for batch,(x,y) in enumerate(dataloader):
            x,y = x.to(device),y.to(device)
            
            test_pred_logits = model(x)
            
            loss = loss_fn(test_pred_logits , y)
            test_loss += loss.item()
            
            test_pred_labels  =  test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
            
        test_loss = test_loss / len(dataloader)
        test_acc = test_acc /len(dataloader)
        return test_loss , test_acc

    
    

def train(model_name: str ,
    model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          scheduler,
          loss_fn:torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):
    
    # create an empty result dictionary
    results = {"train_loss" : [],
              "train_acc": [],
              "test_loss": [],
              "test_acc": []}
    max_acc = 0
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model = model,
                                           dataloader=train_dataloader,
                                           loss_fn = loss_fn,
                                           optimizer=optimizer , scheduler=scheduler)
        
        test_loss, test_acc = test_step(model = model,
                                           dataloader=test_dataloader,
                                           loss_fn = loss_fn)
        
        
         # print whats happening
        print(f"Epoch: {epoch} | Train loss: {train_loss: .4f} | Train acc: {train_acc: .4f} | Test loss: {test_loss: .4f} | Test acc: {test_acc: .4f} ")
        
        
        
        if test_acc > max_acc:
            #1.create models directory
            MODEL_PATH =  Path("models")
            MODEL_PATH.mkdir(parents=True, exist_ok=True)

            # 2. creat model save path
            MODEL_NAME = f"{model_name}.pth"
            MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

            #save the model stat dict
            print(f"saving model to: {MODEL_SAVE_PATH}")
            torch.save(obj=model.state_dict(), f=MODEL_SAVE_PATH)
            max_acc = test_acc
            
        
       
        # update result dic
        
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)
        
    return results

# %%
#set up the bach size hyper parameter
BATCH_SIZE = 100

# TURN DATA SETS INTO ITERABLES (BATCHES)

train_dataloader = DataLoader(dataset  = train_data,
                             batch_size=BATCH_SIZE,
                             shuffle=True)

test_dataloader = DataLoader(dataset  = test_data,
                             batch_size=BATCH_SIZE,
                             shuffle=False)

len(train_dataloader) , len(test_dataloader)
# Out:
# (500, 100)

# %%
model_1 = TinyVGG(input_shape=3 , hidden_units=10,output_shape=len(class_names))
# model_2 = TinyVGGV2(input_shape=3 , hidden_units=10,output_shape=len(class_names))
image_batch , label_batch = next(iter(train_dataloader))
image_batch.shape , label_batch.shape

# model_2(image_batch)
# Out:
# (torch.Size([100, 3, 32, 32]), torch.Size([100]))

# %%
NUM_EPOCHS = 10



loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model_1.parameters(),
                            lr = 0.01)
scheduler =  torch.optim.lr_scheduler.OneCycleLR(optimizer, 0.01, epochs=NUM_EPOCHS, 
                                                steps_per_epoch=len(train_dataloader))



from timeit import default_timer as timer
start_time = timer()
model_0_results = train(model_name="tiny_vgg_withN_and_sch",model= model_0,
                       train_dataloader=  train_dataloader,
                       test_dataloader= test_dataloader,
                       optimizer = optimizer,
                       loss_fn=loss_fn,
                       epochs=NUM_EPOCHS,
                       scheduler=scheduler)
end_time = timer()
print(f"total training time for model_0: {end_time - start_time:.3f} seconds")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0 | Train loss:  10.3197 | Train acc:  0.1329 | Test loss:  9.8735 | Test acc:  0.1673
# saving model to: models\tiny_vgg_withN_and_sch.pth
# Epoch: 1 | Train loss:  10.2897 | Train acc:  0.1343 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 2 | Train loss:  10.3156 | Train acc:  0.1328 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 3 | Train loss:  10.3272 | Train acc:  0.1323 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 4 | Train loss:  10.3240 | Train acc:  0.1333 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 5 | Train loss:  10.3240 | Train acc:  0.1329 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 6 | Train loss:  10.3292 | Train acc:  0.1317 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 7 | Train loss:  10.3251 | Train acc:  0.1321 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 8 | Train loss:  10.2914 | Train acc:  0.1350 | Test loss:  9.8735 | Test acc:  0.1673
# Epoch: 9 | Train loss:  10.2972 | Train acc:  0.1308 | Test loss:  9.8735 | Test acc:  0.1673
# total training time for model_0: 279.657 seconds

# %% [markdown]
# # ResNet

# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# PyTorch data loaders
train_dl = DataLoader(train_data, BATCH_SIZE, shuffle=True, num_workers=3, pin_memory=True)
valid_dl = DataLoader(test_data, BATCH_SIZE*2, num_workers=3, pin_memory=True)

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images[:64], nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cpu')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
    
device = get_default_device()

# %%
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %%
class SimpleResidualBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        
    def forward(self, x):
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        return self.relu2(out) + x # ReLU can be applied before or after adding the input

# %%
simple_resnet = to_device(SimpleResidualBlock(), device)

for images, labels in train_dl:
    out = simple_resnet(images)
    print(out.shape)
    break
    
del simple_resnet, images, labels
torch.cuda.empty_cache()
# Out:
# torch.Size([100, 3, 32, 32])

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        

        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1), 
              nn.BatchNorm2d(out_channels), 
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(ImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        
        self.conv1 = conv_block(in_channels, 64)
        self.conv2 = conv_block(64, 128, pool=True)
        self.res1 = nn.Sequential(conv_block(128, 128), conv_block(128, 128))
        
        self.conv3 = conv_block(128, 256, pool=True)
        self.conv4 = conv_block(256, 512, pool=True)
        self.res2 = nn.Sequential(conv_block(512, 512), conv_block(512, 512))
        
        self.classifier = nn.Sequential(nn.MaxPool2d(4), 
                                        nn.Flatten(), 
                                        nn.Linear(512, num_classes))
        
    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
model_2 = to_device(ResNet9(3, 10), device)
summary(model_2)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet9                                  --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       1,792
# │    └─BatchNorm2d: 2-2                  128
# │    └─ReLU: 2-3                         --
# ├─Sequential: 1-2                        --
# │    └─Conv2d: 2-4                       73,856
# │    └─BatchNorm2d: 2-5                  256
# │    └─ReLU: 2-6                         --
# │    └─MaxPool2d: 2-7                    --
# ├─Sequential: 1-3                        --
# │    └─Sequential: 2-8                   --
# │    │    └─Conv2d: 3-1                  147,584
# │    │    └─BatchNorm2d: 3-2             256
# │    │    └─ReLU: 3-3                    --
# │    └─Sequential: 2-9                   --
# │    │    └─Conv2d: 3-4                  147,584
# │    │    └─BatchNorm2d: 3-5             256
# │    │    └─ReLU: 3-6                    --
# ├─Sequential: 1-4                        --
# │    └─Conv2d: 2-10                      295,168
# │    └─BatchNorm2d: 2-11                 512
# │    └─ReLU: 2-12                        --
# │    └─MaxPool2d: 2-13                   --
# ├─Sequential: 1-5                        --
# │    └─Conv2d: 2-14                      1,180,160
# │    └─BatchNorm2d: 2-15                 1,024
# │    └─ReLU: 2-16                        --
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-6                        --
# │    └─Sequential: 2-18                  --
# │    │    └─Conv2d: 3-7                  2,359,808
# │    │    └─BatchNorm2d: 3-8             1,024
# │    │    └─ReLU: 3-9                    --
# │    └─Sequential: 2-19                  --
# │    │    └─Conv2d: 3-10                 2,359,808
# │    │    └─BatchNorm2d: 3-11            1,024
# │    │    └─ReLU: 3-12                   --
# ├─Sequential: 1-7                        --
# │    └─MaxPool2d: 2-20                   --
# │    └─Flatten: 2-21                     --
# │    └─Linear: 2-22                      5,130
# =================================================================
# Total params: 6,575,370
# Trainable params: 6,575,370
# Non-trainable params: 0
# =================================================================

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
history = [evaluate(model_2, valid_dl)]
history
# Out:
# torch.Size([200, 10]) torch.Size([200])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 history = [evaluate(model_2, valid_dl)]
#       2 history
#
# File E:\araconda\envs\torch\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[56], line 4, in evaluate(model, val_loader)
#       1 @torch.no_grad()
#       2 def evaluate(model, val_loader):
#       3     model.eval()
# ----> 4     outputs = [model.validation_step(batch) for batch in val_loader]
#       5     return model.validation_epoch_end(outputs)
#
# Cell In[56], line 4, in <listcomp>(.0)
#       1 @torch.no_grad()
#       2 def evaluate(model, val_loader):
#       3     model.eval()
# ----> 4     outputs = [model.validation_step(batch) for batch in val_loader]
#       5     return model.validation_epoch_end(outputs)
#
# Cell In[50], line 17, in ImageClassificationBase.validation_step(self, batch)
#      14 out = self(images)                    # Generate predictions
#      15 print(out.shape,labels.shape)
# ---> 17 loss = F.cross_entropy(out, labels)   # Calculate loss
#      18 acc = accuracy(out, labels)           # Calculate accuracy
#      19 return {'val_loss': loss.detach(), 'val_acc': acc}
#
# File E:\araconda\envs\torch\Lib\site-packages\torch\nn\functional.py:3059, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3057 if size_average is not None or reduce is not None:
#    3058     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3059 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# IndexError: Target 49 is out of bounds.

# %%
epochs = 30
max_lr = 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
# %%time
history += fit_one_cycle(epochs, max_lr, model_2, train_dl, valid_dl, 
                             grad_clip=grad_clip, 
                             weight_decay=weight_decay, 
                             opt_func=opt_func)
